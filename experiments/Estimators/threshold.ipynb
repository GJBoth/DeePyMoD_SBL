# %%
# Imports
import numpy as np
import torch

from phimal_utilities.data import Dataset
from phimal_utilities.data.burgers import BurgersDelta
from phimal_utilities.analysis import load_tensorboard

from DeePyMoD_SBL.deepymod_torch.library_functions import library_1D_in
from DeePyMoD_SBL.deepymod_torch.DeepMod import DeepModDynamic
from DeePyMoD_SBL.deepymod_torch.training import train_dynamic
from DeePyMoD_SBL.deepymod_torch.estimators import Threshold
from sklearn.linear_model import LassoCV

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
np.random.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
v = 0.1
A = 1.0

# Making grid
x = np.linspace(-3, 4, 100)
t = np.linspace(0.5, 5.0, 50)
x_grid, t_grid = np.meshgrid(x, t, indexing='ij')

dataset = Dataset(BurgersDelta, v=v, A=A)
X_train, y_train, rand_idx = dataset.create_dataset(x_grid.reshape(-1, 1), t_grid.reshape(-1, 1), n_samples=1000, noise=0.5, random=True, return_idx=True)

# %%
# Making data
estimator = Threshold(LassoCV(cv=5))

config = {'n_in': 2, 'hidden_dims': [30, 30, 30, 30, 30], 'n_out': 1, 'library_function':library_1D_in, 'library_args':{'poly_order':2, 'diff_order': 3}, 'sparsity_estimator': estimator}
model = DeepModDynamic(**config)
optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.999), amsgrad=True)

# %%
train_dynamic(model, X_train, y_train, optimizer, 5000, stopper_kwargs={'ini_epoch':0, 'patience':50}, log_dir='runs/testing/')
# Out:
# | Iteration | Progress | Time remaining |     Loss |      MSE |      Reg |    L1 norm |
#          75      1.50%             144s   -3.57e+00   2.64e-02   4.20e-04   1.15e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-4b68fa439308> in <module>
# ----> 1 train_dynamic(model, X_train, y_train, optimizer, 5000, stopper_kwargs={'ini_epoch':0, 'patience':50}, log_dir='runs/testing/')
#
# ~/DeePyMoD_SBL/src/DeePyMoD_SBL/deepymod_torch/training.py in train_dynamic(model, data, target, optimizer, max_iterations, stopper_kwargs, log_dir)
#     100     for iteration in torch.arange(0, max_iterations + 1):
#     101         # Calculating prediction and library and scaling
# --> 102         prediction, time_deriv_list, sparse_theta_list, coeff_vector_list, theta = model(data)
#     103         coeff_vector_scaled_list = scaling(coeff_vector_list, sparse_theta_list, time_deriv_list)
#     104
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/DeePyMoD_SBL/src/DeePyMoD_SBL/deepymod_torch/DeepMod.py in forward(self, input)
#      56     def forward(self, input):
#      57         prediction = self.network(input)
# ---> 58         time_deriv, theta = self.library((prediction, input))
#      59         sparse_theta, coeff_vector = self.constraints((theta, time_deriv))
#      60         return prediction, time_deriv, sparse_theta, coeff_vector, theta
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/DeePyMoD_SBL/src/DeePyMoD_SBL/deepymod_torch/network.py in forward(self, input)
#      10
#      11     def forward(self, input):
# ---> 12         time_deriv_list, theta = self.library_func(input, **self.library_args)
#      13         return time_deriv_list, theta
#      14
#
# ~/DeePyMoD_SBL/src/DeePyMoD_SBL/deepymod_torch/library_functions.py in library_1D_in(input, poly_order, diff_order)
#      37     # Creating lists for all outputs
#      38     for output in torch.arange(prediction.shape[1]):
# ---> 39         time_deriv, du = library_deriv(data, prediction[:, output:output+1], diff_order)
#      40         u = library_poly(prediction[:, output:output+1], poly_order)
#      41
#
# ~/DeePyMoD_SBL/src/DeePyMoD_SBL/deepymod_torch/library_functions.py in library_deriv(data, prediction, max_order)
#      24         if max_order >1:
#      25             for order in np.arange(1, max_order):
# ---> 26                 du = torch.cat((du, grad(du[:, order:order+1], data, grad_outputs=torch.ones_like(prediction), create_graph=True)[0][:, 1:2]), dim=1)
#      27
#      28     return time_deriv, du
#
# /opt/conda/lib/python3.6/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:

# %%
model.constraints.sparsity_mask
# Out:
# [tensor([False,  True,  True, False,  True,  True, False, False,  True, False,
#          False, False])]

# %%
model.sparsity_estimator.coef_
# Out:
# array([ 0.        , -0.14378089,  0.5912414 ,  0.        ,  0.1905696 ,
#        -0.85686177,  0.        ,  0.        , -0.31651372,  0.        ,
#         0.        ,  0.        ], dtype=float32)

# %%
df_part1 = load_tensorboard('runs/testing/')

# %%
plt.semilogy(df_part1.index, df_part1['MSE_0'])
plt.semilogy(df_part1.index, df_part1['Regression_0'])

# %%
df_part1.keys()
# Out:
# Index(['Total_loss', 'MSE_0', 'Regression_0', 'L1_0', 'coeff_0_0', 'coeff_0_1',
#        'coeff_0_2', 'coeff_0_3', 'coeff_0_4', 'coeff_0_5', 'coeff_0_6',
#        'coeff_0_7', 'coeff_0_8', 'coeff_0_9', 'coeff_0_10', 'coeff_0_11',
#        'scaled_coeff_0_0', 'scaled_coeff_0_1', 'scaled_coeff_0_2',
#        'scaled_coeff_0_3', 'scaled_coeff_0_4', 'scaled_coeff_0_5',
#        'scaled_coeff_0_6', 'scaled_coeff_0_7', 'scaled_coeff_0_8',
#        'scaled_coeff_0_9', 'scaled_coeff_0_10', 'scaled_coeff_0_11'],
#       dtype='object')

# %%
plt.plot(df_part1.index, df_part1['L1_0'])
plt.ylim([1.3, 6])
# Out:
# (1.3, 6)

# %%
coeff_keys = [key for key in df_part1.keys() if key[:5]=='coeff']
scaled_coeff_keys = [key for key in df_part1.keys() if key[:6]=='scaled']

# %%
coeff_keys
# Out:
# ['coeff_0_0',
#  'coeff_0_1',
#  'coeff_0_2',
#  'coeff_0_3',
#  'coeff_0_4',
#  'coeff_0_5',
#  'coeff_0_6',
#  'coeff_0_7',
#  'coeff_0_8',
#  'coeff_0_9',
#  'coeff_0_10',
#  'coeff_0_11']

# %%
plt.plot(df_part1[coeff_keys])
plt.ylim([-2, 2])
# Out:
# (-2, 2)

# %%
plt.plot(np.abs(df_part1[scaled_coeff_keys]), '-')
plt.ylim([0, 1])
plt.axhline(0.1, color='k', linestyle='--')

# %%
plt.plot(np.abs(df_part1[scaled_coeff_keys]).loc[2752], 'o')
plt.plot(np.abs(df_part1[scaled_coeff_keys]).loc[2753], 'x')
plt.axhline(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2752
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-228f2f6b6334> in <module>
# ----> 1 plt.plot(np.abs(df_part1[scaled_coeff_keys]).loc[2752], 'o')
#       2 plt.plot(np.abs(df_part1[scaled_coeff_keys]).loc[2753], 'x')
#       3 plt.axhline(0.1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2752

# %%
active_map = df_part1[coeff_keys][::10]
active_map[active_map!=0.0] = 1.0

# %%
sns.heatmap(active_map)

# %%
np.arange(0, 51, 5)
# Out:
# (11,)

# %%
X_train, y_train, rand_idx = dataset.create_dataset(x_grid.reshape(-1, 1), t_grid.reshape(-1, 1), n_samples=2000, noise=0.0, random=True, return_idx=True, random_state=10)

# %%
X_train
# Out:
# tensor([[ 4.6327, -2.7172],
#         [ 4.4490,  3.2929],
#         [ 3.5306,  3.4343],
#         ...,
#         [ 1.7857,  3.8586],
#         [ 0.8673, -2.4343],
#         [ 1.6939, -2.6465]], requires_grad=True)
